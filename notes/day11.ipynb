# %% [markdown]
# ### string

# %%
"{0} {1}".format("one", "two")
# Out:
# 'one two'

# %%
"%s", %s, "how are you?" %("hello", "Due")

# %%
price = -1225.35653164654
name = "Due"
print_func = print
f"The price is {price:2f}, the name is {name}, print_func :{print_func}"
# Out:
# 'The price is -1225.356532, the name is Due, print_func :<built-in function print>'

# %% [markdown]
# ## Encodings

# %% [markdown]
# ### ASCII

# %%
ord('A')    #convert to number
# Out:
# 65

# %%
chr(95)     #convert to charactor
# Out:
# '_'

# %%
chr(104)
# Out:
# 'h'

# %%
chr(0x68)
# Out:
# 'h'

# %%
map(int,[1,3])

# %% [markdown]
# Base 16 -> hexadecimal -> RAM address, Colors
# Base 10 -> Human interpretation
# Base 2 -> Computer Understand

# %%
hex(0b1101010110011)
# Out:
# '0x1ab3'

# %%
hex(int('10101010010101', 2))
# Out:
# '0x2a95'

# %%
bin() #convert to base 2

# %% [markdown]
# ### Unicode standard

# %% [markdown]
# ### UTF-(int)
#
# unicode tranformation format

# %% [markdown]
# UTF-8 = 1-4 byte (U+0000 to U+10FFFF)
#
# UTF-16 =

# %% [markdown]
# ## file

# %%
open()
